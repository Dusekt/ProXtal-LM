# %%
import sys
import os
sys.path.insert(0, '..')

from scripts.calculate_dataset_stats import calculate_dataset_statistics

# %%
data_dir_path = '../data'
datasets = ['train', 'valid', 'test']

# %%
for i in datasets:
    h5path = os.path.join(data_dir_path, f'{i}_data_3d_esmc')
    print(f'####################### calculating {i} dataset statistics #################################')
    calculate_dataset_statistics(h5path)
    print(f'############################################################################################')
# Out:
# ####################### calculating train dataset statistics #################################
# ...
# 📊 DATASET STATISTICS FOR THESIS
# ...
# Total Unique Proteins (Monomers): 15,853
# Total Crystal Polymorphs:         16,674
# Average Polymorphs per Protein:   1.05
# Max Polymorphs for a single seq:  5
# --------------------------------------------------
# Sequence Length Distribution:
#   Minimum Length: 30 residues
#   Maximum Length: 1575 residues
#   Mean Length:    289.1 residues
#   Median Length:  265.0 residues
# ...
# Polymorph Frequency Breakdown:
#   Proteins with 1 polymorph(s): 15,133 (95.5%)
#   Proteins with 2 polymorph(s): 640 (4.0%)
#   Proteins with 3 polymorph(s): 64 (0.4%)
#   Proteins with 4 polymorph(s): 11 (0.1%)
#   Proteins with 5 polymorph(s): 5 (0.0%)
# ############################################################################################
# ####################### calculating valid dataset statistics #################################
# ...

# %% [markdown]
# # ProXtal-LM — Interactive Metrics Explorer
#
# An interactive plotting tool for exploring training metrics with full
# widget-based controls: series toggles, title/axis editing, colour & style
# pickers, legend/grid toggles, axis-limit sliders, and export to image.
#
# **Requirements:**
# ```
# pip install matplotlib ipywidgets pandas numpy
# # or: uv pip install matplotlib ipywidgets pandas numpy
# ```
#
# **Backend:** Use `%matplotlib widget` for best interactivity (pan/zoom
# built into the canvas). Falls back to `%matplotlib inline` if
# `ipympl` is not installed.

# %%
# Set the matplotlib backend — %matplotlib widget is ideal but needs ipympl.
# If ipympl is not installed, fall back to inline.
try:
    import ipympl  # noqa: F401
    get_ipython().run_line_magic('matplotlib', 'widget')
except ImportError:
    get_ipython().run_line_magic('matplotlib', 'inline')
    print("Tip: install ipympl (`pip install ipympl`) for pan/zoom support.")

# %%
import sys
sys.path.insert(0, '..')

from scripts.interactive_plots import launch, launch_multi

# %% [markdown]
# ## Single-Run Explorer
#
# Point `CSV_PATH` at any `training_metrics.csv` file and run the cell
# below to launch the interactive dashboard.

# %%
CSV_PATH = '../run_checkpoints/v5_smallog_0/training_metrics.csv'
plotter = launch(CSV_PATH)
# Out:
# VBox(children=(VBox(children=(HTML(value='<h3>📊 ProXtal-LM Interactive Plotter</h3>'), HBox(children=(VBox(childr…

# %% [markdown]
# ## Multi-Run Comparison
#
# Compare metrics across all checkpoint runs. Columns are prefixed with the
# run name so every series is individually togglable.

# %%
import glob

csv_files = sorted(glob.glob('../checkpoints/*/training_metrics.csv'))
run_paths = {path.split('/')[-2]: path for path in csv_files}

print(f"Found {len(run_paths)} runs: {list(run_paths.keys())}")

if len(run_paths) > 1:
    multi_plotter = launch_multi(run_paths)
else:
    print("Only one run found — use the single-run explorer above.")
# Out:
# Found 12 runs: ['old', 'v11_esmc_0', 'v2_optimal', 'v3_optimal', 'v3_optimal_2', 'v3_optimal_3', 'v4_small_0', 'v5_smallog_0', 'v7_esmc_0', 'v7_esmc_1', 'v8_esmc_0', 'v9_esmc_0']
# /home/meta/dusekt/ProXtal-LM/notebooks/../scripts/interactive_plots.py:912: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation.
#   merged = merged.merge(other, on="epoch", how="outer")
# /home/meta/dusekt/ProXtal-LM/notebooks/../scripts/interactive_plots.py:642: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self.fig.tight_layout()
# VBox(children=(VBox(children=(HTML(value='<h3>📊 ProXtal-LM Interactive Plotter</h3>'), HBox(children=(VBox(childr…

# %%
import pandas as pd

# %%
df = pd.read_csv('../run_checkpoints/v7_esmc_0/training_metrics.csv')

for i in ['../run_checkpoints/v7_esmc_1/training_metrics.csv']:
    df = pd.concat([df, pd.read_csv(i)])

df = df.sort_values('epoch')

# %%
df.to_csv('../run_checkpoints/v7_esmc_final/training_metrics.csv',index=False)

# %%
df
# Out:
#     epoch       lr  train_loss  train_precision_L  train_precision_L2  \
# 0       1  0.00002    4.257069           0.114417            0.111993
# 1       2  0.00002    4.062731           0.119777            0.112597
# 2       3  0.00002    3.926429           0.135546            0.127399
# 3       4  0.00002    3.810522           0.130050            0.127297
# 4       5  0.00002    3.718478           0.167338            0.174550
# ..    ...      ...         ...                ...                 ...
# 0     175  0.00002    2.952397           0.886657            0.925831
# 3     175  0.00002    2.952392           0.886610            0.926144
# 1     176  0.00002    2.951576           0.887667            0.926455
# 4     176  0.00002    2.951362           0.887436            0.926407
# 2     177  0.00002    2.950339           0.888207            0.927085
#
#     train_precision_L5  train_recall_L  train_f1_L  train_auprc  \
# 0             0.110259        0.012692    0.022518     0.109611
# 1             0.109643        0.013311    0.023606     0.112978
# 2             0.119353        0.015058    0.026682     0.117634
# 3             0.123453        0.014334    0.025425     0.118360
# 4             0.187028        0.019140    0.033873     0.129158
# ..                 ...             ...         ...          ...
# 0             0.952036        0.099579    0.176411     0.533925
# 3             0.952392        0.099569    0.176388     0.534122
# 1             0.952740        0.099696    0.176613     0.534604
# 4             0.952374        0.099644    0.176530     0.534970
# 2             0.953034        0.099734    0.176689     0.535668
#
#     train_crystal_only_precision_L  ...  val_hyp2_tgt0_loss  \
# 0                              0.0  ...            3.742021
# 1                              0.0  ...            3.624475
# 2                              0.0  ...            3.521657
# 3                              0.0  ...            3.441448
# 4                              0.0  ...            3.381664
# ..                             ...  ...                 ...
# 0                              0.0  ...            2.895134
# 3                              0.0  ...            2.894658
# 1                              0.0  ...            2.884967
# 4                              0.0  ...            2.896584
# 2                              0.0  ...            2.895011
#
#     val_hyp2_best_loss  val_loss  val_hyp0_tgt1_loss  val_hyp1_tgt1_loss  \
# 0             3.739322  4.100673            0.440333            0.435276
# 1             3.620950  3.990955            0.430094            0.426904
# 2             3.517484  3.872869            0.419031            0.414658
# 3             3.436859  3.736238            0.406469            0.400748
# 4             3.376701  3.591187            0.393182            0.387913
# ..                 ...       ...                 ...                 ...
# 0             2.895134  2.877946            0.223003            0.221801
# 3             2.894658  2.876861            0.222391            0.221705
# 1             2.884967  2.877446            0.222406            0.221690
# 4             2.896584  2.875321            0.222632            0.221574
# 2             2.895011  2.877260            0.222836            0.221405
#
#     val_hyp2_tgt1_loss  val_hyp0_tgt2_loss  val_hyp1_tgt2_loss  \
# 0             0.405664            0.076182            0.075448
# 1             0.394468            0.074548            0.074147
# 2             0.384681            0.072759            0.072242
# 3             0.377057            0.070775            0.070076
# 4             0.371541            0.068687            0.068103
# ..                 ...                 ...                 ...
# 0             0.224550            0.044374            0.044021
# 3             0.224198            0.044196            0.043966
# 1             0.223449            0.044198            0.043960
# 4             0.224591            0.044225            0.043909
# 2             0.224547            0.044335            0.043942
#
#     val_hyp2_tgt2_loss  best_val_loss
# 0             0.070910            inf
# 1             0.069216       4.100673
# 2             0.067695       3.990955
# 3             0.066491       3.872869
# 4             0.065671       3.736238
# ..                 ...            ...
# 0             0.044735       2.812115
# 3             0.044598       2.812115
# 1             0.044422       2.812115
# 4             0.044655       2.812115
# 2             0.044667       2.812115
#
# [179 rows x 45 columns]
